# %%
import pandas as pd

# %%
mydata = pd.read_csv('Ratios_v2.csv')
# Out:
# /Users/XinyiGuo/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (4,8,11,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
mydata.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  RECORD        BBLE  B  BLOCK  \
# 0           0             0               0       1  1000010101  1      1
# 1           1             1               1       2  1000010201  1      1
# 2           2             2               2       3  1000020001  1      2
# 3           3             3               3       4  1000020023  1      2
# 4           4             4               4       5  1000030001  1      3
#
#    LOT EASEMENT                  OWNER  ...   R9_by_B R1_by_ALL     R2_by_ALL  \
# 0  101      NaN  U S GOVT LAND & BLDGS  ...  0.053790  0.008662  5.980538e-05
# 1  201      NaN  U S GOVT LAND & BLDGS  ...  0.008853  6.362706  3.843280e-05
# 2    1      NaN  DEPT OF GENERAL SERVI  ...  0.000844  0.055418  8.047898e-07
# 3   23      NaN  DEPARTMENT OF BUSINES  ...  0.004050  0.018991  2.572970e-06
# 4    1      NaN   PARKS AND RECREATION  ...  0.519432  0.141632  1.650068e-04
#
# ...

# %%
mydata.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'RECORD', 'BBLE', 'B',
#        'BLOCK', 'LOT', 'EASEMENT', 'OWNER', 'BLDGCL', 'TAXCLASS', 'LTFRONT',
#        'LTDEPTH', 'EXT', 'STORIES', 'FULLVAL', 'AVLAND', 'AVTOT', 'EXLAND',
#        'EXTOT', 'EXCD1', 'STADDR', 'ZIP', 'EXMPTCL', 'BLDFRONT', 'BLDDEPTH',
#        'AVLAND2', 'AVTOT2', 'EXLAND2', 'EXTOT2', 'EXCD2', 'PERIOD', 'YEAR',
#        'VALTYPE', 'ZIP3', 'LOTAREA', 'BLDAREA', 'BLDVOL', 'R1', 'R2', 'R3',
#        'R4', 'R5', 'R6', 'R7', 'R8', 'R9', 'R1_by_ZIP', 'R2_by_ZIP',
#        'R3_by_ZIP', 'R4_by_ZIP', 'R5_by_ZIP', 'R6_by_ZIP', 'R7_by_ZIP',
#        'R8_by_ZIP', 'R9_by_ZIP', 'R1_by_ZIP3', 'R2_by_ZIP3', 'R3_by_ZIP3',
#        'R4_by_ZIP3', 'R5_by_ZIP3', 'R6_by_ZIP3', 'R7_by_ZIP3', 'R8_by_ZIP3',
#        'R9_by_ZIP3', 'R1_by_TAXCLASS', 'R2_by_TAXCLASS', 'R3_by_TAXCLASS',
#        'R4_by_TAXCLASS', 'R5_by_TAXCLASS', 'R6_by_TAXCLASS', 'R7_by_TAXCLASS',
# ...

# %%
col = ['R1_by_ZIP', 'R2_by_ZIP',
       'R3_by_ZIP', 'R4_by_ZIP', 'R5_by_ZIP', 'R6_by_ZIP', 'R7_by_ZIP',
       'R8_by_ZIP', 'R9_by_ZIP', 'R1_by_ZIP3', 'R2_by_ZIP3', 'R3_by_ZIP3',
       'R4_by_ZIP3', 'R5_by_ZIP3', 'R6_by_ZIP3', 'R7_by_ZIP3', 'R8_by_ZIP3',
       'R9_by_ZIP3', 'R1_by_TAXCLASS', 'R2_by_TAXCLASS', 'R3_by_TAXCLASS',
       'R4_by_TAXCLASS', 'R5_by_TAXCLASS', 'R6_by_TAXCLASS', 'R7_by_TAXCLASS',
       'R8_by_TAXCLASS', 'R9_by_TAXCLASS', 'R1_by_B', 'R2_by_B', 'R3_by_B',
       'R4_by_B', 'R5_by_B', 'R6_by_B', 'R7_by_B', 'R8_by_B', 'R9_by_B',
       'R1_by_ALL', 'R2_by_ALL', 'R3_by_ALL', 'R4_by_ALL', 'R5_by_ALL',
       'R6_by_ALL', 'R7_by_ALL', 'R8_by_ALL', 'R9_by_ALL']

# %%
df = mydata.loc[:,col]

# %%
df
# Out:
#          R1_by_ZIP  R2_by_ZIP  R3_by_ZIP  R4_by_ZIP  R5_by_ZIP  R6_by_ZIP  \
# 0         0.032443   0.018360   0.030073   0.047845   0.008059   0.013198
# 1        23.831995   0.011799   0.004949  13.143162   0.001937   0.000812
# 2         0.207572   0.000247   0.000472   0.577689   0.000205   0.000391
# 3         0.071132   0.000790   0.002264   0.206750   0.000683   0.001958
# 4         0.530493   0.050656   0.290405   1.761368   0.050058   0.286934
# ...            ...        ...        ...        ...        ...        ...
# 1070989   0.174367   0.000124   0.000134   0.177394   0.000045   0.000049
# 1070990   0.110305   0.000144   0.000156   0.057826   0.000027   0.000029
# 1070991   0.095088   0.000138   0.000187   0.089816   0.000047   0.000063
# 1070992   0.220080   0.000178   0.000242   0.153916   0.000045   0.000061
# 1070993   0.338940   0.000145   0.000196   0.308874   0.000047   0.000064
#
#          R7_by_ZIP  R8_by_ZIP  R9_by_ZIP  R1_by_ZIP3  ...   R9_by_B  \
# ...

# %% [markdown]
# ## Standard scaling

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
scaler = StandardScaler()

# %%
scaled_data = scaler.fit_transform(df)

# %%
scaled_data
# Out:
# array([[-1.21107432e-01, -3.01458926e-02, -2.98989415e-02, ...,
#         -1.17265211e-02, -1.72158650e-03, -1.71590987e-03],
#        [ 2.85784029e+00, -3.03473884e-02, -3.06733998e-02, ...,
#          7.13267377e-02, -1.72163176e-03, -1.71594009e-03],
#        [-9.91868534e-02, -3.07021366e-02, -3.08114121e-02, ...,
#         -1.11153740e-02, -1.72171144e-03, -1.71594548e-03],
#        ...,
#        [-1.13266255e-01, -3.07054990e-02, -3.08202066e-02, ...,
#         -1.18299730e-02, -1.72171271e-03, -1.71594583e-03],
#        [-9.76212633e-02, -3.07042617e-02, -3.08185199e-02, ...,
#         -1.18197071e-02, -1.72171264e-03, -1.71594580e-03],
#        [-8.27436719e-02, -3.07052831e-02, -3.08199122e-02, ...,
#         -1.18053131e-02, -1.72171269e-03, -1.71594582e-03]])

# %%
scaled_data.mean()
# Out:
# 6.651930627908077e-19

# %%
scaled_data.std()
# Out:
# 0.9999999999999999

# %%
scaledDf = pd.DataFrame(scaled_data, columns=col)

# %%
scaledDf
# Out:
#          R1_by_ZIP  R2_by_ZIP  R3_by_ZIP  R4_by_ZIP  R5_by_ZIP  R6_by_ZIP  \
# 0        -0.121107  -0.030146  -0.029899  -0.057902  -0.023596  -0.023580
# 1         2.857840  -0.030347  -0.030673   0.738448  -0.023742  -0.023876
# 2        -0.099187  -0.030702  -0.030811  -0.025681  -0.023783  -0.023886
# 3        -0.116265  -0.030685  -0.030756  -0.048239  -0.023772  -0.023848
# 4        -0.058767  -0.029154  -0.021874   0.046300  -0.022597  -0.017039
# ...            ...        ...        ...        ...        ...        ...
# 1070989  -0.103343  -0.030706  -0.030822  -0.050024  -0.023787  -0.023894
# 1070990  -0.111362  -0.030705  -0.030821  -0.057295  -0.023787  -0.023895
# 1070991  -0.113266  -0.030705  -0.030820  -0.055350  -0.023787  -0.023894
# 1070992  -0.097621  -0.030704  -0.030819  -0.051452  -0.023787  -0.023894
# 1070993  -0.082744  -0.030705  -0.030820  -0.042029  -0.023787  -0.023894
#
#          R7_by_ZIP  R8_by_ZIP  R9_by_ZIP  R1_by_ZIP3  ...   R9_by_B  \
# ...

# %%
scaledDf.describe()
# Out:
#           R1_by_ZIP     R2_by_ZIP     R3_by_ZIP     R4_by_ZIP     R5_by_ZIP  \
# count  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06
# mean   2.864741e-17 -3.676936e-17 -2.540715e-18  1.224718e-17 -2.657472e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.251682e-01 -3.070972e-02 -3.082597e-02 -6.081183e-02 -2.378784e-02
# 25%   -7.249414e-02 -3.070809e-02 -3.082502e-02 -4.108439e-02 -2.378762e-02
# 50%   -2.299195e-02 -3.070284e-02 -3.082106e-02 -1.932823e-02 -2.378655e-02
# 75%    1.735076e-02 -3.067704e-02 -3.080325e-02  9.474593e-04 -2.378307e-02
# max    6.086337e+02  3.954853e+02  3.969824e+02  6.183537e+02  3.908797e+02
#
#           R6_by_ZIP     R7_by_ZIP     R8_by_ZIP     R9_by_ZIP    R1_by_ZIP3  \
# count  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06
# mean   2.355355e-17 -8.836974e-18  1.500720e-17  1.225746e-17 -1.866228e-16
# ...

# %%
matrix = scaledDf

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pca = PCA()
pca.fit(matrix)
pca_samples = pca.transform(matrix)

# %%
fig, ax = plt.subplots(figsize=(14, 5))
sns.set(font_scale=1)
plt.step(range(matrix.shape[1]), pca.explained_variance_ratio_.cumsum(), where='mid',
         label='cumulative explained variance')
sns.barplot(np.arange(1,matrix.shape[1]+1), pca.explained_variance_ratio_, alpha=0.5, color = 'g',
            label='individual explained variance')
plt.xlim(0, 10)

ax.set_xticklabels([s if int(s.get_text())%2 == 0 else '' for s in ax.get_xticklabels()])

plt.ylabel('Explained variance', fontsize = 14)
plt.xlabel('Principal components', fontsize = 14)
plt.legend(loc='upper right', fontsize = 13);

# %% [markdown]
# ## Second z-scale transform

# %%
pca_samples
# Out:
# array([[-7.02836987e-02, -1.08207649e-01, -3.63328804e-02, ...,
#         -4.33491496e-07,  5.93170381e-08, -3.23889706e-09],
#        [ 3.30568112e-01,  7.84808726e-01, -3.51557266e-01, ...,
#         -1.10596115e-05, -1.00058651e-06,  2.84051896e-07],
#        [-6.51024195e-02, -9.74946804e-02, -4.15713376e-02, ...,
#         -1.02673767e-07,  1.33684873e-08,  1.90163145e-08],
#        ...,
#        [-5.32985665e-02, -9.69381074e-02, -4.51538538e-02, ...,
#         -8.53159177e-08, -9.60130703e-08,  3.74962981e-08],
#        [-4.92075836e-02, -8.26279712e-02, -4.71562087e-02, ...,
#         -1.25322341e-07, -1.25325964e-07,  3.57976415e-08],
#        [-4.74615465e-02, -6.27121684e-02, -4.81807374e-02, ...,
#          5.51348931e-08, -1.00993945e-07,  3.76615239e-08]])

# %%
df = pd.DataFrame(pca_samples)

# %%
df.describe()
# Out:
#                  0             1             2             3             4   \
# count  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06
# mean   1.966820e-16 -8.518234e-17  1.441752e-16  1.921654e-16 -2.825370e-16
# std    4.978233e+00  3.069714e+00  2.009055e+00  1.631337e+00  1.346406e+00
# min   -7.177072e-02 -1.387311e+02 -3.335492e+02 -7.873194e+02 -5.030274e+02
# 25%   -5.242100e-02 -7.904188e-02 -5.741904e-02 -6.347489e-02 -2.788832e-02
# 50%   -4.247382e-02 -5.785713e-02 -5.261466e-02 -3.396435e-02 -1.715993e-03
# 75%   -3.456113e-02 -3.795881e-02 -4.573833e-02 -6.270454e-03  2.753753e-02
# max    4.379173e+03  2.295241e+03  7.993188e+02  9.840246e+02  7.756734e+02
#
#                  5             6             7             8             9   \
# count  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06
# mean  -4.294652e-17  1.035479e-19  8.773624e-17 -2.088565e-16 -3.752734e-17
# ...

# %%
df = df.iloc[:,0:5]

# %%
df.describe()
# Out:
#                   0             1             2             3             4
# count  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06
# mean   1.966820e-16 -8.518234e-17  1.441752e-16  1.921654e-16 -2.825370e-16
# std    4.978233e+00  3.069714e+00  2.009055e+00  1.631337e+00  1.346406e+00
# min   -7.177072e-02 -1.387311e+02 -3.335492e+02 -7.873194e+02 -5.030274e+02
# 25%   -5.242100e-02 -7.904188e-02 -5.741904e-02 -6.347489e-02 -2.788832e-02
# 50%   -4.247382e-02 -5.785713e-02 -5.261466e-02 -3.396435e-02 -1.715993e-03
# 75%   -3.456113e-02 -3.795881e-02 -4.573833e-02 -6.270454e-03  2.753753e-02
# max    4.379173e+03  2.295241e+03  7.993188e+02  9.840246e+02  7.756734e+02

# %%
scaler = StandardScaler()

# %%
scaled_data = scaler.fit_transform(df)

# %%
scaledDf = pd.DataFrame(scaled_data)

# %%
scaledDf
# Out:
#                 0         1         2         3         4
# 0       -0.014118 -0.035250 -0.018085 -0.057771  0.043979
# 1        0.066403  0.255662 -0.174987  1.219237 -1.297856
# 2       -0.013077 -0.031760 -0.020692 -0.042738  0.027369
# 3       -0.013936 -0.034337 -0.019152 -0.053920  0.039657
# 4       -0.009362 -0.024893 -0.019999 -0.012066 -0.006431
# ...           ...       ...       ...       ...       ...
# 1070989 -0.010736 -0.027416 -0.022520 -0.049799  0.040250
# 1070990 -0.011926 -0.032035 -0.021162 -0.055530  0.044075
# 1070991 -0.010706 -0.031579 -0.022475 -0.055385  0.043620
# 1070992 -0.009885 -0.026917 -0.023472 -0.049217  0.040538
# 1070993 -0.009534 -0.020429 -0.023982 -0.040651  0.035073
#
# [1070994 rows x 5 columns]

# %%
scaledDf.describe()
# Out:
#                   0             1             2             3             4
# count  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06
# mean  -3.360822e-17  8.194248e-17 -2.181445e-17  8.380311e-17  1.095101e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.441691e-02 -4.519352e+01 -1.660230e+02 -4.826224e+02 -3.736077e+02
# 25%   -1.053005e-02 -2.574896e-02 -2.858014e-02 -3.890975e-02 -2.071317e-02
# 50%   -8.531910e-03 -1.884774e-02 -2.618878e-02 -2.081996e-02 -1.274499e-03
# 75%   -6.942451e-03 -1.236559e-02 -2.276611e-02 -3.843753e-03  2.045262e-02
# max    8.796644e+02  7.477055e+02  3.978584e+02  6.032016e+02  5.761068e+02

# %% [markdown]
# ###  Calculate fraud score

# %%
scaledDf['score'] = (scaledDf[0]**2+scaledDf[1]**2+scaledDf[2]**2+scaledDf[3]**2+scaledDf[4]**2)**(0.5)

# %%
scaledDf
# Out:
#                 0         1         2         3         4     score
# 0       -0.014118 -0.035250 -0.018085 -0.057771  0.043979  0.083908
# 1        0.066403  0.255662 -0.174987  1.219237 -1.297856  1.808690
# 2       -0.013077 -0.031760 -0.020692 -0.042738  0.027369  0.064679
# 3       -0.013936 -0.034337 -0.019152 -0.053920  0.039657  0.078867
# 4       -0.009362 -0.024893 -0.019999 -0.012066 -0.006431  0.035975
# ...           ...       ...       ...       ...       ...       ...
# 1070989 -0.010736 -0.027416 -0.022520 -0.049799  0.040250  0.073987
# 1070990 -0.011926 -0.032035 -0.021162 -0.055530  0.044075  0.081501
# 1070991 -0.010706 -0.031579 -0.022475 -0.055385  0.043620  0.081162
# 1070992 -0.009885 -0.026917 -0.023472 -0.049217  0.040538  0.073748
# 1070993 -0.009534 -0.020429 -0.023982 -0.040651  0.035073  0.062976
#
# [1070994 rows x 6 columns]

# %%
scaledDf['RECORD'] = mydata['RECORD']

# %%
scaledDf
# Out:
#                 0         1         2         3         4     score   RECORD
# 0       -0.014118 -0.035250 -0.018085 -0.057771  0.043979  0.083908        1
# 1        0.066403  0.255662 -0.174987  1.219237 -1.297856  1.808690        2
# 2       -0.013077 -0.031760 -0.020692 -0.042738  0.027369  0.064679        3
# 3       -0.013936 -0.034337 -0.019152 -0.053920  0.039657  0.078867        4
# 4       -0.009362 -0.024893 -0.019999 -0.012066 -0.006431  0.035975        5
# ...           ...       ...       ...       ...       ...       ...      ...
# 1070989 -0.010736 -0.027416 -0.022520 -0.049799  0.040250  0.073987  1070990
# 1070990 -0.011926 -0.032035 -0.021162 -0.055530  0.044075  0.081501  1070991
# 1070991 -0.010706 -0.031579 -0.022475 -0.055385  0.043620  0.081162  1070992
# 1070992 -0.009885 -0.026917 -0.023472 -0.049217  0.040538  0.073748  1070993
# 1070993 -0.009534 -0.020429 -0.023982 -0.040651  0.035073  0.062976  1070994
#
# [1070994 rows x 7 columns]

# %%
scaledDf.sort_values('score', inplace = True)

# %%
scaledDf = scaledDf.reset_index()

# %%
scaledDf['score_1'] = scaledDf.index

# %%
scaledDf
# Out:
#           index           0           1           2           3           4  \
# 0        968636   -0.001136   -0.014272   -0.001859    0.002333    0.003105
# 1        968635   -0.003063   -0.014585   -0.006294    0.000910    0.003880
# 2        985604    0.003886   -0.014391    0.010375    0.003501    0.002920
# 3        968649    0.002775   -0.009926    0.004439    0.015311   -0.005743
# 4        985148    0.004683   -0.012159    0.012024    0.008523   -0.002848
# ...         ...         ...         ...         ...         ...         ...
# 1070989  337274    6.483405  231.231872    3.147289  207.558807  476.786788
# 1070990  337273    7.837106  279.412184    3.806797  250.812324  576.106813
# 1070991  776305   37.912128  200.832368  -64.777370  603.201627 -356.593788
# 1070992  565391  879.664411  -12.364286 -166.023046   46.702616  -61.093767
# 1070993    7055   15.375723  747.705518   50.740410 -482.622439 -154.755576
#
#               score  RECORD  score_1
# ...

# %%
scaledDf.sort_values('RECORD', inplace = True)

# %%
scaledDf
# Out:
#            index         0         1         2         3         4     score  \
# 899366         0 -0.014118 -0.035250 -0.018085 -0.057771  0.043979  0.083908
# 1063994        1  0.066403  0.255662 -0.174987  1.219237 -1.297856  1.808690
# 746414         2 -0.013077 -0.031760 -0.020692 -0.042738  0.027369  0.064679
# 847484         3 -0.013936 -0.034337 -0.019152 -0.053920  0.039657  0.078867
# 64497          4 -0.009362 -0.024893 -0.019999 -0.012066 -0.006431  0.035975
# ...          ...       ...       ...       ...       ...       ...       ...
# 816872   1070989 -0.010736 -0.027416 -0.022520 -0.049799  0.040250  0.073987
# 870435   1070990 -0.011926 -0.032035 -0.021162 -0.055530  0.044075  0.081501
# 866817   1070991 -0.010706 -0.031579 -0.022475 -0.055385  0.043620  0.081162
# 815310   1070992 -0.009885 -0.026917 -0.023472 -0.049217  0.040538  0.073748
# 730720   1070993 -0.009534 -0.020429 -0.023982 -0.040651  0.035073  0.062976
#
#           RECORD  score_1
# ...

# %%
scaledDf = scaledDf.reset_index()

# %%
scaledDf
# Out:
#          level_0    index         0         1         2         3         4  \
# 0         899366        0 -0.014118 -0.035250 -0.018085 -0.057771  0.043979
# 1        1063994        1  0.066403  0.255662 -0.174987  1.219237 -1.297856
# 2         746414        2 -0.013077 -0.031760 -0.020692 -0.042738  0.027369
# 3         847484        3 -0.013936 -0.034337 -0.019152 -0.053920  0.039657
# 4          64497        4 -0.009362 -0.024893 -0.019999 -0.012066 -0.006431
# ...          ...      ...       ...       ...       ...       ...       ...
# 1070989   816872  1070989 -0.010736 -0.027416 -0.022520 -0.049799  0.040250
# 1070990   870435  1070990 -0.011926 -0.032035 -0.021162 -0.055530  0.044075
# 1070991   866817  1070991 -0.010706 -0.031579 -0.022475 -0.055385  0.043620
# 1070992   815310  1070992 -0.009885 -0.026917 -0.023472 -0.049217  0.040538
# 1070993   730720  1070993 -0.009534 -0.020429 -0.023982 -0.040651  0.035073
#
#             score   RECORD  score_1
# ...

# %% [markdown]
# ## Add score_1 back to the original dataset

# %%
mydata['score_1'] = scaledDf['score_1']

# %%
mydata
# Out:
#          Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1   RECORD        BBLE  B  \
# 0                 0             0               0        1  1000010101  1
# 1                 1             1               1        2  1000010201  1
# 2                 2             2               2        3  1000020001  1
# 3                 3             3               3        4  1000020023  1
# 4                 4             4               4        5  1000030001  1
# ...             ...           ...             ...      ...         ... ..
# 1070989     1070989       1070989         1070989  1070990  5080500083  5
# 1070990     1070990       1070990         1070990  1070991  5080500086  5
# 1070991     1070991       1070991         1070991  1070992  5080500089  5
# 1070992     1070992       1070992         1070992  1070993  5080500092  5
# 1070993     1070993       1070993         1070993  1070994  5080500094  5
#
#          BLOCK  LOT EASEMENT                  OWNER  ... R1_by_ALL  \
# ...
